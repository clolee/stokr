# %% [markdown]
# # Visualization 01 - 파이썬 데이터 시각화 (Matplotlib)
#
# ## matplotlib
# * http://matplotlib.org/ 2002년 John Hunter
# * MATLAB과 유사한 인터페이스를 지원하기 위해개발 시작
# * 출판 수준의 차트
# * LaTEX 수식 지원
# * 다양한 형식으로 이미지 저장(PNG, PDF, SVG, EPS 등)
# * 확대, 회전과 같은 인터랙티브한 드로잉
# * 인터랙티브한 비주얼라이제인션, 혹은 일괄 그래픽 이미지 파일을 생성
#
# ## 그래픽 라이브러리를 사용하는 이유
# * programmatically 제어
# * 정교한 제어와 reproducing

# %%
# 주피터 노트북 페이지 안에 matplotlib 그리도록 하는 옵션 
# (새로운 창이 뜨지 않는다)

# %matplotlib inline

# %% [markdown]
# ## pyplot, pylab
# * matplotlib 가 전체 패키지
# * matplotlib.pyplot는 matplotlib 내의 모듈
# * pylab = matplotlib.pyplot + numpy
#
# ## pylab (MATLAB 스타일)
# * pylab 은 matplotlib과 함께 설치되는 모듈
# * numpy 와 pyplot를 같은 네임스페이스에서 사용할 수 있도록 묶어주는 역할
# * MATLAB과 유사하게 사용할 수 있어, MATLAB에 익숙한 사용자들에게 편리

# %%
from pylab import *

x = linspace(0, 5, 10)
y = x ** 2

plot(x, y, 'r')
show()

# %% [markdown]
# ## pyplot
# * numpy와 matplotlib.pyplot 를 따로 import 하여 사용
# * 일관성을 위해 분리하여 쓰는 스타일을 권장
# * IPython과 같은 대화적인 환경에서는 pylab와 pyplot 편의성 측면에서 큰 차이가 없다.
# * pyplot 은 figure, axes을 자동으로 생성
# * 파이썬 스타일, 객체지향 스타일
# * 프로그래밍에 권장

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 5, 10)
y = x ** 2

print(x, y)

plt.plot(x, y, 'r')
plt.show()
# Out:
# [ 0.          0.55555556  1.11111111  1.66666667  2.22222222  2.77777778
#   3.33333333  3.88888889  4.44444444  5.        ] [  0.           0.30864198   1.2345679    2.77777778   4.9382716
#    7.71604938  11.11111111  15.12345679  19.75308642  25.        ]

# %% [markdown]
# ## 간단한 수식 표현

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 5, 10)
y = x ** 2

plt.plot(x, y, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.title('$y=x^2$ Graph')  # LaTEX syntax!!!

plt.show()

# %% [markdown]
# ## 간단한 그리기

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터의 누적값을 통한 추세 분석
data = np.random.randn(100).cumsum()  # cumulative sum
plt.plot(data)

# %% [markdown]
# ## mapplotlib 전역 설정

# %%
import matplotlib.pyplot as plt

# 설정값 얻기
fig_size = plt.rcParams["figure.figsize"]
line_width = plt.rcParams['lines.linewidth'] = 2
lines_color = plt.rcParams['lines.color'] = 'r'

# 값 설정
plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.color'] = 'b'

# %% [markdown]
# ## Figure, subplot()
# * 그래프는 Figure 객체에 그려진다.
# * Figure안에 1개 이상의 서브플롯(subplot)을 생성하고 그 위에 그래프를 그린다.
# * plt.plot() 는 최근에 만들어진 Figure의 서브플롯에 그래프를 그린다.
# * 만일 서브플롯이 존재하지 않으면 새로 생성한다.

# %%
data = np.random.randn(100).cumsum()

plt.figure(facecolor='lightgrey', edgecolor='r')
plt.plot(data)

# %% [markdown]
# ## subplot()

# %%
d1 = np.random.randn(100).cumsum()
d2 = np.random.randn(100).cumsum()

plt.subplot(211)
plt.plot(d1) # 바로 이전 subplot에 그린다.
plt.subplot(212)
plt.plot(d2, 'r--')

# %%
d1 = np.random.randn(100).cumsum()
d2 = np.random.randn(100).cumsum()

plt.subplot(221)
plt.plot(d1)
plt.subplot(224)
plt.plot(d2, 'r--')
plt.subplot(224)
plt.plot(d1)

# %% [markdown]
# ## 라인 스타일과 색

# %%
plt.subplot(1,2,1)
plt.plot(d2, d1, 'g*-')

plt.subplot(1,2,2)
plt.plot(d1, d2, 'r--')

plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 0.5, 0.5]) # lower, bottom, width, height (0~1)

ax.plot(d1, d2, 'r')

# %% [markdown]
# ## figure(도형)와 axes(축)
# figure(도형)내에 여러개의 axes(축)를 만들고, 각 축에 그래프를 그릴 수 있다.

# %%
fig = plt.figure()

ax1 = fig.add_axes([0.1, 0.1, 0.9, 0.9]) # main
ax2 = fig.add_axes([0.2, 0.5, 0.3, 0.3]) # inner

# main chart
ax1.plot(x, y, 'r')
ax1.set_xlabel('x')
ax1.set_ylabel('y')

# inner chart
ax2.plot(x, y, 'g')
ax2.set_title('inner chart')

# %% [markdown]
# ## matplotlib의 레이아웃 매니저
# subplots()를 사용

# %%
fig, axes = plt.subplots()

axes.plot(x, y, 'r')
axes.set_title('title')

# %% [markdown]
# ## 차트 크기와 DPI
# * figure() 에서 figsize로 크기를 지정 (inch 단위)
# * dpi(dot per inch)를 지정하여 해상도를 명시할 수 있다.
# * figsize=(12,6), dpi=100 이라면 1200 x 600 pixel 해상도

# %%
fig = plt.figure(figsize=(12,6), dpi=100)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16,5), dpi=100)

x = np.arange(0, 10)

axes[0].plot(x, x ** 0.5)
axes[1].plot(x, x ** 1)
axes[2].plot(x, x ** 2)

plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(16,5), dpi=100)

x = np.arange(0, 10)

axes[0][0].plot(x, x ** 0.5)
axes[1][1].plot(x, x ** 1)
axes[0][2].plot(x, x ** 2)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,4))

x = np.arange(100)
y = np.random.randint(-50,50,100).cumsum()

ax.plot(x, y, 'r')
ax.set_title('Price Simulation')

# %%
fig, ax = plt.subplots(figsize=(16,4))

# generate date array from today to 100 day after
base = datetime.datetime.today()
date_list = [base + datetime.timedelta(days=x) for x in range(0, 100)]

x = date_list
y = np.random.randint(-50,50,100).cumsum()

ax.plot(date_list, y, 'r')
ax.set_title('Price Simulation')

# %% [markdown]
# ## 이미지 저장
# * PNG, JPG 는 비트맵 이미지 (bitmap image)
# * eps, svg, pdf 는 벡터 이미지 (vector image)

# %%
fig.savefig("price-simul.png")
fig.savefig("price-simul.png", dpi=200)
fig.savefig("price-simul.svg")

# %%
ax1 = plt.subplot(211)
plt.plot(d1)
ax2 = plt.subplot(212, sharex=ax1, sharey=ax1)
plt.plot(d2, 'r--')

# %% [markdown]
# ## 타이틀, 레이블, 범례
# 타이틀 title, 레이블 label, 범례 legend

# %%
fig, ax = plt.subplots(figsize=(16,4))

x = np.arange(100)
y1 = np.random.randint(-50,50,100).cumsum()
y2 = np.random.randint(-50,50,100).cumsum()
y3 = np.random.randint(-50,50,100).cumsum()

ax.plot(x, y1, 'r')
ax.plot(x, y2, 'g')
ax.plot(x, y3, 'b')

#  타이틀
ax.set_title("title")

# 레이블
ax.set_xlabel("x")
ax.set_ylabel("y")

# 범례
ax.legend(["Red", "Green", "Blue"]);

# %%
fig, ax = plt.subplots(figsize=(16,4))

x = np.arange(100)
y1 = np.random.randint(-50,50,100).cumsum()
y2 = np.random.randint(-50,50,100).cumsum()
y3 = np.random.randint(-50,50,100).cumsum()

# plot()의 label로 범례 레이블을 지정
ax.plot(x, y1, 'r', label='Red')
ax.plot(x, y2, 'g', label='Green')
ax.plot(x, y3, 'b', label='Blue')

# 범례
ax.legend(loc=3)

# %%
##  범례의 위치

ax.legend(loc=0) # 알아서
ax.legend(loc=1) # 오른쪽 위
ax.legend(loc=2) # 왼쪽 위
ax.legend(loc=3) # 왼쪽 아래
ax.legend(loc=4) # 오른쪽 아래

# %% [markdown]
# ## 텍스트
# LaTeX 수식, 폰트 크기, 폰트 패밀리
# * LaTeX 수식을 $로 묶어준다
#
# 몇 가지 수식 예제
# * y=x2 ( y=x^2 )
# * Σni=0( \Sigma_{i=0}^n )
# * α,β,γ ( \alpha, \beta, \gama )
# * $x_i$ (xi)
#
# ## 한글
# * 한글을 사용하려면 폰트를 지정해야 한다.
# * subplots()를 사용하여 ax(서브플롯)을 얻고,
# * 제목과 축에 각각 fontproperties 로 폰트를 지정하여 그린다

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fp = fm.FontProperties(fname="H2HDRM.TTF")

# %%
fig, ax = plt.subplots()
ax.set_title('한글 제목', fontproperties=fp)

# %%
fig, ax = plt.subplots()

x = np.arange(0, 5, 0.5)

ax.plot(x, x**2, label='$y = x^2$')
ax.plot(x, x**3, label='$y = x^3$')
ax.set_xlabel('$x$', fontsize=20)
ax.set_ylabel('$y$', fontsize=20)
ax.legend(loc=2); # 왼쪽 위

# %%
# 기본 크기로  변경
matplotlib.rcParams.update({'font.size': 12, 'font.family': 'sans'})
matplotlib.rcParams.update({'figure.figsize':(6, 4)})

# %%
fig, ax = plt.subplots()

x = np.arange(-1, 1, 0.1)

ax.plot(x, x**2, x, x**3)

ax.text(0.15, 0.2, "$y=x^2$", fontsize=20, color="blue")
ax.text(0.65, 0.1, r"$y=x^3$", fontsize=20, color="green");

# %% [markdown]
# ## 색상
# * 하나의 색상(color)는 RGB 값을 16진수로 표현

# %%
fig, ax = subplots()

x = np.arange(0, 5, 0.5)

ax.plot(x, x**2.0, color='#FF0000') # 'red' = 'r' = '#FF0000'
ax.plot(x, x**2.5, color='green')    # 'green' = 'g', ''#00FF00'
ax.plot(x, x**3.0, color='b') # B

# %% [markdown]
# ## 간격조절, 축 공유
# * 축 공유: sharex, sharey 속성에 공유할 축(axis)를 지정
# * 축의 눈금 감추기: setp(대상, visible=False)

# %%
# x축 눈금(tick labels)을 보이지 않게 한다.
ax1 = plt.subplot(211)
setp( ax1.get_xticklabels(), visible=False)
plt.plot(d1)
ax2 = plt.subplot(212, sharex=ax1, sharey=ax1)
plt.plot(d2, 'r--')

# 서브플롯 사이 간격 조정 
plt.subplots_adjust(hspace=0)

# 그리드 표시
ax1.grid(True)
ax2.grid(True)

# %% [markdown]
# ## subplots
# * subplots: 서브플롯을 한번에 생성
# * subplots_adjust: 간격 조절

# %%
# sharex, sharey 는 두개의 x나 y를 긴쪽을 기준으로 동시에 표현하도록 한다.
fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, figsize=(16,8))

# 간격을 없앤다.
plt.subplots_adjust(wspace=0, hspace=0)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, figsize=(16,8))
fig.subplots_adjust(wspace =0.05, hspace=0.1) # 좁은간격

x = range(0, 100)
for ax in axes.reshape(-1):
    y = np.random.randn(100).cumsum()
    ax.grid(True)
    ax.plot(x, y, 'r')

# %% [markdown]
# ## subplots

# %%
fig, ax = subplots(2, 3)
fig.tight_layout()

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((3,3), (0,0), colspan=3)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2)
ax3 = plt.subplot2grid((3,3), (1,2), rowspan=2)
ax4 = plt.subplot2grid((3,3), (2,0))
ax5 = plt.subplot2grid((3,3), (2,1))
fig.tight_layout()

# %% [markdown]
# ## 색상, 라인, 마커
# * plot(x, y, '색/스타일/마커 문자조합')
#   예) 'bo--' (파란색 선, 원형 마커, 점선), 'r+' (빨간색 선, 십자마커)
# * itertools 의 cycle 활용, 돌아가며 바꾸기

# %%
from itertools import cycle
colors = cycle(['r', 'g', 'b', 'c', 'm', 'y', 'k'])

print (next(colors)) #차례로 하나씩 반환
print (next(colors))
print (next(colors))
# Out:
# r
# g
# b

# %%
from itertools import cycle
line_styles = cycle(['-', '--', '-.', ':'])
markers = cycle(['o', '^.', 's', 'x', 'd'])

for i in range(0,10):
    print (next(line_styles) + next(markers))
# Out:
# -o
# --^.
# -.s
# :x
# -d
# --o
# -.^.
# :s
# -x
# --d

# %%
from itertools import cycle
color = cycle(['r', 'g', 'b', 'c', 'm', 'y', 'k'])
line_styles = cycle(['-', '--', '-.', ':'])
markers = cycle(['o', '^', 's', 'x', 'd'])

fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, figsize=(16,8))
fig.subplots_adjust(wspace =0.05, hspace=0.1) # 좁은간격

x = range(0, 50)
for ax in axes.reshape(-1):
    ax.grid(True)
    for i in range(3): #하나의 서브플롯에 3개씩
        y = np.random.randn(50).cumsum()
        style = next(color) + next(line_styles) + next(markers)
        #print (style) #색상, 라인, 마커 문자열
        ax.plot(x, y, style)

# %% [markdown]
# ## 컬러 cycle

# %%
from itertools import cycle
colors = cycle([ "#C41F3B", "#FF7D0A", "#ABD473", "#69CCF0", "#00FF96", "#F58CBA", "#FFF569", "#0070DE", "#9482C9", "#C79C6E" ])
line_styles = cycle(['-', '--', '-.', ':'])
markers = cycle(['o', '^', 's', 'x', 'd'])

fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, figsize=(16,8))
fig.subplots_adjust(wspace =0.05, hspace=0.1) # 좁은간격

x = range(0, 50)
for ax in axes.reshape(-1):
    ax.grid(True)
    for i in range(3): #하나의 서브플롯에 3개씩
        y = np.random.randn(50).cumsum()
        style = next(line_styles) + next(markers)
        ax.plot(x, y, style, color=next(colors))

# %%
import matplotlib.pyplot as plt
from datetime import datetime
from pandas_datareader import data, wb

df = data.get_data_yahoo('^KS11', datetime(2014, 1, 1), datetime(2014, 1, 30))
x_val = df.index
y_val = df['Adj Close']

fig = plt.figure(figsize=(16,4))
ax = fig.add_subplot(111)

ax.set_xticks(range(0, len(x_val)))
ax.set_xticklabels(df.index, rotation=50, fontsize="small")

ax.set_title('Jan 2014 KOSPI index')
ax.set_xlabel('date')
plt.plot(y_val, "red")

# %%
y = np.random.randn(10)
print (y)
plt.plot([x for x in range(10)], y)
# Out:
# [-0.12058615 -0.08952668  1.25274831 -0.21560812  0.03034051 -0.32675457
#  -0.00622577  0.84569446  0.07094798  0.16470225]

# %% [markdown]
# ## 범위지정

# %%
fig, axes = subplots(1, 3, figsize=(12, 4))

x = np.linspace(0,5,5)

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom range");

# %% [markdown]
# ## 틱과 틱 레이블

# %%
import numpy as np

fig, ax = subplots(figsize=(10, 4))

ax.plot(np.arange(1,6), np.random.randint(1,150,5))

ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xticklabels('ABCDE', fontsize=18)

yticks = [0, 50, 100, 150]
ax.set_yticks(yticks)
ax.set_yticklabels(["%.1f" % y for y in yticks], fontsize=18)

plt.show()

# %% [markdown]
# ## 그리드

# %%
fig, axes = subplots(1, 2, figsize=(10,3))

# default grid appearance
axes[0].plot(x, x**2, x, x**3, lw=2)
axes[0].grid(True)

# custom grid appearance
axes[1].plot(x, x**2, x, x**3, lw=2)
axes[1].grid(color='b', alpha=0.5, linestyle='dashed', linewidth=0.5) # 있어빌리티
